# %%
currency_from = input("What is the currency of your country? ").strip().upper()
currencies = [
    "EUR", "USD", "GBP", "CAD", "AUD", "ALL", "DZD", "AOA", "AMD", "AZN", "BSD", "BHD", "BDT", 
    "BBD", "BYN", "BZD", "BMD", "BOB", "BAM", "BWP", "BRL", "GBP", "BND", "BGN", "BIF", "KHR", 
    "CAD", "CVE", "KYD", "XOF", "XAF", "XPF", "CLP", "CNY", "COP", "CRC", "HRK", "CUP", "CZK", 
    "DKK", "DJF", "DOP", "XCD", "EGP", "ETB", "EUR", "FJD", "GMD", "GEL", "GHS", "GTQ", "GNF", 
    "HTG", "HNL", "HKD", "ISK", "INR", "IDR", "IRR", "IQD", "ILS", "JMD", "JPY", "JOD", "KZT", 
    "KES", "KRW", "KWD", "KGS", "LAK", "LBP", "LSL", "LYD", "MOP", "MKD", "MWK", "MYR", "MUR", 
    "MXN", "MDL", "MAD", "MMK", "NAD", "NPR", "ANG", "NZD", "NIO", "NGN", "NOK", "OMR", "PKR", 
    "PAB", "PYG", "PEN", "PLN", "PHP", "QAR", "RON", "RUB", "RWF", "SAR", "RSD", "SCR", "SGD", 
    "SOS", "ZAR", "LKR", "SDG", "SZL", "SEK", "CHF", "SYP", "TWD", "TZS", "THB", "TTD", "TND", 
    "TRY", "TMT", "UGX", "UAH", "AED", "UYU", "USD", "UZS", "VES", "VND", "YER", "ZMW"
]

for currency in currencies:
    currency_lower = currency.lower()
    link = f"https://www.exchange-rates.org/exchange-rate-history/{currency_from}-{currency_lower}-2024"
    print(link)
# Out:
# What is the currency of your country?  PHP
# https://www.exchange-rates.org/exchange-rate-history/PHP-eur-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-usd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-gbp-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-cad-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-aud-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-all-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-dzd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-aoa-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-amd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-azn-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-bsd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-bhd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-bdt-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-bbd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-byn-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-bzd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-bmd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-bob-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-bam-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-bwp-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-brl-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-gbp-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-bnd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-bgn-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-bif-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-khr-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-cad-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-cve-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-kyd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-xof-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-xaf-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-xpf-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-clp-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-cny-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-cop-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-crc-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-hrk-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-cup-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-czk-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-dkk-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-djf-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-dop-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-xcd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-egp-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-etb-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-eur-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-fjd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-gmd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-gel-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-ghs-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-gtq-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-gnf-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-htg-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-hnl-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-hkd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-isk-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-inr-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-idr-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-irr-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-iqd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-ils-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-jmd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-jpy-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-jod-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-kzt-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-kes-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-krw-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-kwd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-kgs-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-lak-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-lbp-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-lsl-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-lyd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-mop-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-mkd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-mwk-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-myr-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-mur-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-mxn-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-mdl-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-mad-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-mmk-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-nad-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-npr-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-ang-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-nzd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-nio-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-ngn-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-nok-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-omr-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-pkr-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-pab-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-pyg-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-pen-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-pln-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-php-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-qar-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-ron-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-rub-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-rwf-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-sar-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-rsd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-scr-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-sgd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-sos-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-zar-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-lkr-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-sdg-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-szl-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-sek-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-chf-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-syp-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-twd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-tzs-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-thb-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-ttd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-tnd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-try-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-tmt-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-ugx-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-uah-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-aed-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-uyu-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-usd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-uzs-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-ves-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-vnd-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-yer-2024
# https://www.exchange-rates.org/exchange-rate-history/PHP-zmw-2024
